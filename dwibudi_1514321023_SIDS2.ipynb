# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1, figsize=(19,10))

# Sample it down to only the Java Island region
lon_min, lon_max = 105.21, 114.60527777778
lat_min, lat_max = -8.78, -5.8758333333333

data = pd.DataFrame({
'lat':[112.6426427,112.5617417,112.5252467,113.166456,113.3732598,114.3949536,110.3470241,110.3398252,108.6952968,107.5731164,106.863809,105.3577406],
'lon':[ -7.2756141,-7.9786277,-7.4548864,-7.7723105,-8.2655356,-8.14118,-7.0247246, -7.803249,-7.4616468,-6.9034443,-6.7340184,-6.6188681,],
'name':['Surabaya', 'Malang', 'Sidoarjo', 'Probolinggo','Jember','Banyuwangi','Semarang','Yogyakarta','Cilacap','Bandung','Cianjur','Pandeglang']
})

# Mercator of Java Island
m1 = Basemap(llcrnrlat=lat_min,
             urcrnrlat=lat_max,
             llcrnrlon=lon_min,
             urcrnrlon=lon_max)

m1.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m1.fillcontinents(color='green', alpha=0.7, lake_color='grey')
m1.drawcoastlines(linewidth=0.1, color="white")

plt.title("Pemetaan kota di Jawa ")
m1.plot(data['lat'], data['lon'], linestyle='none', marker="o", markersize=10, alpha=0.6, c="orange", markeredgecolor="black", markeredgewidth=0.5)

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(1, figsize=(19,13))

# Sample it down to only the Java Island region
lon_min, lon_max = 105.21, 114.60527777778
lat_min, lat_max = -8.78, -5.8758333333333

# Mercator of Java Island
m1 = Basemap(projection='merc',
             llcrnrlat=lat_min,
             urcrnrlat=lat_max,
             llcrnrlon=lon_min,
             urcrnrlon=lon_max)

m1.drawmapboundary(fill_color='#FF9E2C', linewidth=0)
m1.fillcontinents(color='yellow', alpha=0.7, lake_color='yellow')
m1.drawcoastlines(linewidth=0.1, color="white")

lons = [ 110.747438, 112.0052398, 112.0315737, 111.4471048, 109.6393978, 109.6247797, 110.1824187, 110.2408406, 110.482478, 110.7837064, 111.1139287, 111.6663692, 111.9459742, 111.9783312, 112.4041252, 113.7390028, 112.6426427,112.8699891,112.5252467,113.166456,113.3732598,114.3949536,110.3470241,110.3398252,108.6952968,107.5731164,106.8329425,106.6890835]
lats = [ -6.644140,-6.8921193,-7.1229523,-6.5599851,-6.8959407,-7.3997086,-7.4730525,-7.6896952,-7.6747783,-7.5592076,-7.4324027,-7.6150516,-7.8424163,-7.5613891,-7.4714876,-7.798502,-7.2756141,-7.6514338,-7.4548864,-7.7723105,-8.2655356,-8.14118,-7.0247246, -7.803249,-7.4616468,-6.9034443,-6.2845208,-6.2297279,]
labels = ['JEPARA','LAMONGAN','GRESIK','TUBAN','PEKALONGAN','WONOSOBO','MAGELANG','SLEMAN','KLATEN','SURAKARTA','NGAWI','NGANJUK','KEDIRI','JOMBANG','MOJOKERTO','SITUBONDO','SURABAYA', 'PASURUAN', 'SIDOARJO', 'PROBOLINGGO','JEMBER','BANYUWANGI','SEMARANG','YOGYAKARTA','CILACAP','BANDUNG','BEKASI','JAKARTA']

x_offsets = [10000, -30000, -25000]
y_offsets = [5000, -25000, -25000]

x,y = m1(lons, lats)
m1.plot(x, y, 'bo', markersize=10)

plt.title("Pemetaan Kota di Pulau Jawa")

for label, x, y in zip(labels, x, y):
    plt.text(x+10000, y+5000, label)
    
plt.show()
